# %%
import numpy as np

# %% [markdown]
# ### Shape: Checking shape

# %%
porosity2d = np.array([[0.5 , 0.34, 0.56, 0.98, 0.12],[0.34, 0.65, 0.12, 0.87, 0.23]])

# %%
porosity2d = np.array([[0.5 , 0.34, 0.56, 0.98, 0.12],[0.34, 0.65, 0.12, 0.87, 0.23]])

# %%
porosity2d
# Out:
# array([[0.5 , 0.34, 0.56, 0.98, 0.12],
#        [0.34, 0.65, 0.12, 0.87, 0.23]])

# %%
porosity2d.ndim
# Out:
# 2

# %%
porosity2d
# Out:
# array([[0.5 , 0.34, 0.56, 0.98, 0.12],
#        [0.34, 0.65, 0.12, 0.87, 0.23]])

# %%
porosity2d.shape
# Out:
# (2, 5)

# %%
perm = np.array([[[ 1,  2,  3,  5],[ 4,  5,  6,  7]],
                 [[ 1,  2,  3,  2],[ 3,  4,  5,  5]],
                 [[43, 45, 67, 56],[32, 54, 65, 64]]])

# %%
perm
# Out:
# array([[[ 1,  2,  3,  5],
#         [ 4,  5,  6,  7]],
#
#        [[ 1,  2,  3,  2],
#         [ 3,  4,  5,  5]],
#
#        [[43, 45, 67, 56],
#         [32, 54, 65, 64]]])

# %%
perm.shape
# Out:
# (3, 2, 4)

# %% [markdown]
# # Using inbuilt methods for generating arrays

# %% [markdown]
# ## Arange: Return an array with evenly spaced elements in the given interval.
#     - np.arange(start,stop,step)

# %%
#Make an array of pressures ranging from 0 to 5000 psi with a step size of 500 psi
pressures = np.arange(0,5500,500)

# %%
pressures
# Out:
# array([   0,  500, 1000, 1500, 2000, 2500, 3000, 3500, 4000, 4500, 5000])

# %%
pressures.ndim
# Out:
# 1

# %% [markdown]
# ## Linspace: Creates lineraly spaced array
# - Evenly spaced numbers over a specified interval
# - Creating n datapoints between two points

# %%
np.arange(0,1.01,0.01010101)
# Out:
# array([0.        , 0.01010101, 0.02020202, 0.03030303, 0.04040404,
#        0.05050505, 0.06060606, 0.07070707, 0.08080808, 0.09090909,
#        0.1010101 , 0.11111111, 0.12121212, 0.13131313, 0.14141414,
#        0.15151515, 0.16161616, 0.17171717, 0.18181818, 0.19191919,
#        0.2020202 , 0.21212121, 0.22222222, 0.23232323, 0.24242424,
#        0.25252525, 0.26262626, 0.27272727, 0.28282828, 0.29292929,
#        0.3030303 , 0.31313131, 0.32323232, 0.33333333, 0.34343434,
#        0.35353535, 0.36363636, 0.37373737, 0.38383838, 0.39393939,
#        0.4040404 , 0.41414141, 0.42424242, 0.43434343, 0.44444444,
#        0.45454545, 0.46464646, 0.47474747, 0.48484848, 0.49494949,
#        0.5050505 , 0.51515151, 0.52525252, 0.53535353, 0.54545454,
#        0.55555555, 0.56565656, 0.57575757, 0.58585858, 0.59595959,
#        0.6060606 , 0.61616161, 0.62626262, 0.63636363, 0.64646464,
#        0.65656565, 0.66666666, 0.67676767, 0.68686868, 0.69696969,
#        0.7070707 , 0.71717171, 0.72727272, 0.73737373, 0.74747474,
#        0.75757575, 0.76767676, 0.77777777, 0.78787878, 0.79797979,
#        0.8080808 , 0.81818181, 0.82828282, 0.83838383, 0.84848484,
#        0.85858585, 0.86868686, 0.87878787, 0.88888888, 0.89898989,
#        0.9090909 , 0.91919191, 0.92929292, 0.93939393, 0.94949494,
#        0.95959595, 0.96969696, 0.97979797, 0.98989898, 0.99999999])

# %%
# Create saturation array from 0 to 1 having 100 points
saturations = np.linspace(0,1,100)
saturations
# Out:
# array([0.        , 0.01010101, 0.02020202, 0.03030303, 0.04040404,
#        0.05050505, 0.06060606, 0.07070707, 0.08080808, 0.09090909,
#        0.1010101 , 0.11111111, 0.12121212, 0.13131313, 0.14141414,
#        0.15151515, 0.16161616, 0.17171717, 0.18181818, 0.19191919,
#        0.2020202 , 0.21212121, 0.22222222, 0.23232323, 0.24242424,
#        0.25252525, 0.26262626, 0.27272727, 0.28282828, 0.29292929,
#        0.3030303 , 0.31313131, 0.32323232, 0.33333333, 0.34343434,
#        0.35353535, 0.36363636, 0.37373737, 0.38383838, 0.39393939,
#        0.4040404 , 0.41414141, 0.42424242, 0.43434343, 0.44444444,
#        0.45454545, 0.46464646, 0.47474747, 0.48484848, 0.49494949,
#        0.50505051, 0.51515152, 0.52525253, 0.53535354, 0.54545455,
#        0.55555556, 0.56565657, 0.57575758, 0.58585859, 0.5959596 ,
#        0.60606061, 0.61616162, 0.62626263, 0.63636364, 0.64646465,
#        0.65656566, 0.66666667, 0.67676768, 0.68686869, 0.6969697 ,
#        0.70707071, 0.71717172, 0.72727273, 0.73737374, 0.74747475,
#        0.75757576, 0.76767677, 0.77777778, 0.78787879, 0.7979798 ,
#        0.80808081, 0.81818182, 0.82828283, 0.83838384, 0.84848485,
#        0.85858586, 0.86868687, 0.87878788, 0.88888889, 0.8989899 ,
#        0.90909091, 0.91919192, 0.92929293, 0.93939394, 0.94949495,
#        0.95959596, 0.96969697, 0.97979798, 0.98989899, 1.        ])

# %%
len(saturations)
# Out:
# 100

# %%
saturations.ndim
# Out:
# 1

# %% [markdown]
# # Indexing Arrays

# %% [markdown]
# ## Accesing elements

# %%
perm = np.array([[[1,2,3],[2,3,4]],[[34,45,56],[34,78,23]]])

# %%
perm
# Out:
# array([[[ 1,  2,  3],
#         [ 2,  3,  4]],
#
#        [[34, 45, 56],
#         [34, 78, 23]]])

# %%
perm[1]
# Out:
# array([[34, 45, 56],
#        [34, 78, 23]])

# %%
perm[1][0]
# Out:
# array([34, 45, 56])

# %%
perm[1][0][1]
# Out:
# 45

# %%
perm[1,0,1]
# Out:
# 45

# %% [markdown]
# # Slicing Arrays
#
# - cutting the subset from superset

# %%
perm = np.array([[13,23,32,43,54],[43,55,60,7,8],[12,34,45,77,87],[2,55,39,82,49]])

# %%
perm
# Out:
# array([[13, 23, 32, 43, 54],
#        [43, 55, 60,  7,  8],
#        [12, 34, 45, 77, 87],
#        [ 2, 55, 39, 82, 49]])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize = (10,8))
plt.title('Reservoir Pemeability Grids')
sns.heatmap(perm)
# Out:
# <AxesSubplot:title={'center':'Reservoir Pemeability Grids'}>

# %%
perm[1:3,2:4]
# Out:
# array([[60,  7],
#        [45, 77]])

# %%
perm_stimulated = perm[1:3,2:4]*1.2

# %%
perm_stimulated
# Out:
# array([[72. ,  8.4],
#        [54. , 92.4]])

# %%
perm
# Out:
# array([[13, 23, 32, 43, 54],
#        [43, 55, 60,  7,  8],
#        [12, 34, 45, 77, 87],
#        [ 2, 55, 39, 82, 49]])

# %%
perm[1:3,2:4] = perm_stimulated

# %%
perm
# Out:
# array([[13, 23, 32, 43, 54],
#        [43, 55, 72,  8,  8],
#        [12, 34, 54, 92, 87],
#        [ 2, 55, 39, 82, 49]])

# %%
plt.figure(figsize = (8,6))
plt.title('Reservoir Pemeability Grids')
sns.heatmap(perm)
# Out:
# <AxesSubplot:title={'center':'Reservoir Pemeability Grids'}>

# %% [markdown]
# # Random Number Generation

# %% [markdown]
# ### Randint : Generating Random Integer
# - np.random.randint(min,max,shape)

# %%
np.random.randint(250,350,(3,4,3))
# Out:
# array([[[261, 272, 330],
#         [253, 310, 336],
#         [260, 301, 261],
#         [309, 278, 266]],
#
#        [[296, 309, 314],
#         [267, 261, 258],
#         [302, 336, 256],
#         [302, 310, 298]],
#
#        [[319, 329, 263],
#         [337, 341, 266],
#         [277, 315, 288],
#         [260, 267, 280]]])

# %%
np.random.randint(40)
# Out:
# 27

# %% [markdown]
# ### rand: Generating Random FLoat between 0 and 1
# - provide size

# %%
porosity = np.random.rand(5,4,2)

# %%
porosity
# Out:
# array([[[0.08606514, 0.71528212],
#         [0.0772598 , 0.51296209],
#         [0.86385659, 0.21895251],
#         [0.30472031, 0.55893675]],
#
#        [[0.8365687 , 0.94760078],
#         [0.59941776, 0.23678633],
#         [0.78598195, 0.78271706],
#         [0.48080657, 0.61237529]],
#
#        [[0.69708111, 0.25300355],
#         [0.11836601, 0.36561468],
#         [0.90596882, 0.84131679],
#         [0.42966359, 0.38564178]],
#
#        [[0.17656619, 0.19065994],
#         [0.36160562, 0.6305182 ],
#         [0.1111556 , 0.38994636],
#         [0.38439601, 0.17778229]],
#
#        [[0.26523367, 0.66881896],
#         [0.87350067, 0.23761482],
#         [0.18202591, 0.91872303],
#         [0.67811309, 0.79872   ]]])

# %% [markdown]
# ## Arithmetics Functions:

# %%
# Addition:
a = [1,2,3,44,5]
b = [4,5,6,7,8]
c= a+b
c
# Out:
# [1, 2, 3, 44, 5, 4, 5, 6, 7, 8]

# %%
ara = np.array(a)
arb = np.array(b)
arc = ara +arb
arc
# Out:
# array([ 5,  7,  9, 51, 13])

# %%
a*b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-82-8ce765dcfa30> in <module>
# ----> 1 a*b
#
# TypeError: can't multiply sequence by non-int of type 'list'

# %%
3*a
# Out:
# [1, 2, 3, 44, 5, 1, 2, 3, 44, 5, 1, 2, 3, 44, 5]

# %%
ara*arb
# Out:
# array([  4,  10,  18, 308,  40])

# %%
4551/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-85-c82d36dbfcfb> in <module>
# ----> 1 4551/0
#
# ZeroDivisionError: division by zero

# %%
np.array(42523454)/0
# Out:
# <ipython-input-86-a7f1ac096154>:1: RuntimeWarning: divide by zero encountered in true_divide
#   np.array(42523454)/0
# inf

# %% [markdown]
# # Line Plot using Matplotlib

# %%
x = np.linspace(-10,10)

# %%
x
# Out:
# array([-10.        ,  -9.59183673,  -9.18367347,  -8.7755102 ,
#         -8.36734694,  -7.95918367,  -7.55102041,  -7.14285714,
#         -6.73469388,  -6.32653061,  -5.91836735,  -5.51020408,
#         -5.10204082,  -4.69387755,  -4.28571429,  -3.87755102,
#         -3.46938776,  -3.06122449,  -2.65306122,  -2.24489796,
#         -1.83673469,  -1.42857143,  -1.02040816,  -0.6122449 ,
#         -0.20408163,   0.20408163,   0.6122449 ,   1.02040816,
#          1.42857143,   1.83673469,   2.24489796,   2.65306122,
#          3.06122449,   3.46938776,   3.87755102,   4.28571429,
#          4.69387755,   5.10204082,   5.51020408,   5.91836735,
#          6.32653061,   6.73469388,   7.14285714,   7.55102041,
#          7.95918367,   8.36734694,   8.7755102 ,   9.18367347,
#          9.59183673,  10.        ])

# %%
len(x)
# Out:
# 50

# %%
#Step 1: Import the library(s). 
import matplotlib.pyplot as plt

#Step 2: create numpy arrays for x and y.
x = np.linspace(-10,10)
y = x**2

#Step 3: Plot now. 
plt.plot(x,y)

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
#Customization
plt.style.use('fivethirtyeight')
plt.figure(figsize=(6,6))  #6X6 canvas.
# plt.style.use('default')
z = x**3
# 1. generate the plot. Add a label.
plt.plot(x,y,"g--",label='It is a parabola')
plt.plot(x,z,"r*",label='It is a exponent 3')
#2. Set x axis label
plt.xlabel('This is X-Axis')

#3. Set y axis label.
plt.ylabel('This is Y-Axis')

#4. Set the title.
plt.title('TITLE here.')

#5. set the grid. 
plt.grid(True)

#6. display the label in a legend.
plt.legend(loc='best')

# %% [markdown]
# # Pandas
# Ms Excel of Python but powerful
# This library helps us import | create | work with data in the form of tables.
#
#
# The tables are called DataFrames.
#
# 1. We can directly convert a Dictionary into a DataFrame.
# 2. We can import excel-sheets or CSV files (most popular) into DF.
# 3. We can manipulate and use these tables in a  user-friendly way.

# %%
#Converting Dictionary into DataFrame
#Step 1: Import Pandas with an alias 'pd'
import pandas as pd


#Step 2: Create your dictionary
Rock_Properties = {'phi': [0.2,0.40,0.30,0.25,0.270],
                'perm': [100,20,150,130,145],
                'lith': ['sandstone','shale','limestone','limestone','sandstone']}

# %%
Rock_Properties
# Out:
# {'phi': [0.2, 0.4, 0.3, 0.25, 0.27],
#  'perm': [100, 20, 150, 130, 145],
#  'lith': ['sandstone', 'shale', 'limestone', 'limestone', 'sandstone']}

# %%
#Step 3: Create your Table.
rock_table = pd.DataFrame(Rock_Properties)

#Step 4: Print your table.
rock_table
# Out:
#     phi  perm       lith
# 0  0.20   100  sandstone
# 1  0.40    20      shale
# 2  0.30   150  limestone
# 3  0.25   130  limestone
# 4  0.27   145  sandstone

# %%
type(rock_table)
# Out:
# pandas.core.frame.DataFrame

# %%
#Adding New Column
rock_table['Saturation'] = [0.14,0.25,0.45,0.37,np.nan]
rock_table
# Out:
#     phi  perm       lith  Saturation
# 0  0.20   100  sandstone        0.14
# 1  0.40    20      shale        0.25
# 2  0.30   150  limestone        0.45
# 3  0.25   130  limestone        0.37
# 4  0.27   145  sandstone         NaN

# %%
rock_table['lith']
# Out:
# 0    sandstone
# 1        shale
# 2    limestone
# 3    limestone
# 4    sandstone
# Name: lith, dtype: object

# %%
rock_table['Saturation%'] = rock_table['Saturation']*100

# %%
rock_table
# Out:
#     phi  perm       lith  Saturation  Saturation%
# 0  0.20   100  sandstone        0.14         14.0
# 1  0.40    20      shale        0.25         25.0
# 2  0.30   150  limestone        0.45         45.0
# 3  0.25   130  limestone        0.37         37.0
# 4  0.27   145  sandstone         NaN          NaN

# %%
#Importing from csv or excel files
volve = pd.read_csv('vpd.csv')
#Similarly excel file can be read by- 
#df = pd.read_excel('\path\filename.csv')

# %%
volve
# Out:
#          DATEPRD  NPD_WELL_BORE_CODE NPD_WELL_BORE_NAME  ON_STREAM_HRS  \
# 0      07-Apr-14                7405         15/9-F-1 C            0.0
# 1      08-Apr-14                7405         15/9-F-1 C            0.0
# 2      09-Apr-14                7405         15/9-F-1 C            0.0
# 3      10-Apr-14                7405         15/9-F-1 C            0.0
# 4      11-Apr-14                7405         15/9-F-1 C            0.0
# ...          ...                 ...                ...            ...
# 15629  14-Sep-16                5769           15/9-F-5            0.0
# 15630  15-Sep-16                5769           15/9-F-5            0.0
# 15631  16-Sep-16                5769           15/9-F-5            0.0
# 15632  17-Sep-16                5769           15/9-F-5            0.0
# 15633  18-Sep-16                5769           15/9-F-5            0.0
#
#        AVG_DOWNHOLE_PRESSURE  AVG_DOWNHOLE_TEMPERATURE  AVG_DP_TUBING  \
# 0                      0.000                     0.000          0.000
# 1                        NaN                       NaN            NaN
# 2                        NaN                       NaN            NaN
# 3                        NaN                       NaN            NaN
# 4                    310.376                    96.876        277.278
# ...                      ...                       ...            ...
# 15629                    NaN                       NaN            NaN
# 15630                    NaN                       NaN            NaN
# 15631                    NaN                       NaN            NaN
# 15632                    NaN                       NaN            NaN
# 15633                    NaN                       NaN            NaN
#
#        AVG_ANNULUS_PRESS  AVG_CHOKE_SIZE_P AVG_CHOKE_UOM  AVG_WHP_P  \
# 0                  0.000           0.00000             %      0.000
# 1                  0.000           1.00306             %      0.000
# 2                  0.000           0.97901             %      0.000
# 3                  0.000           0.54576             %      0.000
# 4                  0.000           1.21599             %     33.098
# ...                  ...               ...           ...        ...
# 15629              0.273           0.63609             %      0.078
# 15630              0.287           0.67079             %      0.085
# 15631              0.286           0.66439             %      0.085
# 15632              0.272           0.62466             %      0.075
# 15633                NaN               NaN           NaN        NaN
#
#        AVG_WHT_P  DP_CHOKE_SIZE  BORE_OIL_VOL  BORE_GAS_VOL  BORE_WAT_VOL  \
# 0          0.000          0.000           0.0           0.0           0.0
# 1          0.000          0.000           0.0           0.0           0.0
# 2          0.000          0.000           0.0           0.0           0.0
# 3          0.000          0.000           0.0           0.0           0.0
# 4         10.480         33.072           0.0           0.0           0.0
# ...          ...            ...           ...           ...           ...
# 15629      0.229          0.019           0.0           0.0           0.0
# 15630      0.229          0.006           0.0           0.0           0.0
# 15631      0.229          0.012           0.0           0.0           0.0
# 15632      0.228          0.026           0.0           0.0           0.0
# 15633        NaN          0.000           NaN           NaN           NaN
#
#        BORE_WI_VOL   FLOW_KIND WELL_TYPE
# 0              NaN  production        WI
# 1              NaN  production        OP
# 2              NaN  production        OP
# 3              NaN  production        OP
# 4              NaN  production        OP
# ...            ...         ...       ...
# 15629          NaN  production        OP
# 15630          NaN  production        OP
# 15631          NaN  production        OP
# 15632          NaN  production        OP
# 15633          0.0   injection        WI
#
# [15634 rows x 19 columns]

# %%
volve.head(10)
# Out:
#      DATEPRD  NPD_WELL_BORE_CODE NPD_WELL_BORE_NAME  ON_STREAM_HRS  \
# 0  07-Apr-14                7405         15/9-F-1 C            0.0
# 1  08-Apr-14                7405         15/9-F-1 C            0.0
# 2  09-Apr-14                7405         15/9-F-1 C            0.0
# 3  10-Apr-14                7405         15/9-F-1 C            0.0
# 4  11-Apr-14                7405         15/9-F-1 C            0.0
# 5  12-Apr-14                7405         15/9-F-1 C            0.0
# 6  13-Apr-14                7405         15/9-F-1 C            0.0
# 7  14-Apr-14                7405         15/9-F-1 C            0.0
# 8  15-Apr-14                7405         15/9-F-1 C            0.0
# 9  16-Apr-14                7405         15/9-F-1 C            0.0
#
#    AVG_DOWNHOLE_PRESSURE  AVG_DOWNHOLE_TEMPERATURE  AVG_DP_TUBING  \
# 0                  0.000                     0.000          0.000
# 1                    NaN                       NaN            NaN
# 2                    NaN                       NaN            NaN
# 3                    NaN                       NaN            NaN
# 4                310.376                    96.876        277.278
# 5                303.501                    96.923        281.447
# 6                303.535                    96.959        276.032
# 7                303.782                    96.969        282.787
# 8                303.858                    97.021        289.941
# 9                303.792                    97.066        299.672
#
#    AVG_ANNULUS_PRESS  AVG_CHOKE_SIZE_P AVG_CHOKE_UOM  AVG_WHP_P  AVG_WHT_P  \
# 0                0.0           0.00000             %      0.000      0.000
# 1                0.0           1.00306             %      0.000      0.000
# 2                0.0           0.97901             %      0.000      0.000
# 3                0.0           0.54576             %      0.000      0.000
# 4                0.0           1.21599             %     33.098     10.480
# 5                0.0           3.08702             %     22.053      8.704
# 6                0.0           1.96237             %     27.503      9.423
# 7                0.0           0.00000             %     20.996      8.131
# 8                0.0          31.14186             %     13.918      8.498
# 9                0.0           0.00000             %      4.120      8.821
#
#    DP_CHOKE_SIZE  BORE_OIL_VOL  BORE_GAS_VOL  BORE_WAT_VOL  BORE_WI_VOL  \
# 0          0.000           0.0           0.0           0.0          NaN
# 1          0.000           0.0           0.0           0.0          NaN
# 2          0.000           0.0           0.0           0.0          NaN
# 3          0.000           0.0           0.0           0.0          NaN
# 4         33.072           0.0           0.0           0.0          NaN
# 5         22.053           0.0           0.0           0.0          NaN
# 6         16.163           0.0           0.0           0.0          NaN
# 7         20.737           0.0           0.0           0.0          NaN
# 8         12.182           0.0           0.0           0.0          NaN
# 9          1.490           0.0           0.0           0.0          NaN
#
#     FLOW_KIND WELL_TYPE
# 0  production        WI
# 1  production        OP
# 2  production        OP
# 3  production        OP
# 4  production        OP
# 5  production        OP
# 6  production        OP
# 7  production        OP
# 8  production        OP
# 9  production        OP

# %%
volve.tail(10)
# Out:
#          DATEPRD  NPD_WELL_BORE_CODE NPD_WELL_BORE_NAME  ON_STREAM_HRS  \
# 15624  09-Sep-16                5769           15/9-F-5            0.0
# 15625  10-Sep-16                5769           15/9-F-5            0.0
# 15626  11-Sep-16                5769           15/9-F-5            0.0
# 15627  12-Sep-16                5769           15/9-F-5            0.0
# 15628  13-Sep-16                5769           15/9-F-5            0.0
# 15629  14-Sep-16                5769           15/9-F-5            0.0
# 15630  15-Sep-16                5769           15/9-F-5            0.0
# 15631  16-Sep-16                5769           15/9-F-5            0.0
# 15632  17-Sep-16                5769           15/9-F-5            0.0
# 15633  18-Sep-16                5769           15/9-F-5            0.0
#
#        AVG_DOWNHOLE_PRESSURE  AVG_DOWNHOLE_TEMPERATURE  AVG_DP_TUBING  \
# 15624                    NaN                       NaN            NaN
# 15625                    NaN                       NaN            NaN
# 15626                    NaN                       NaN            NaN
# 15627                    NaN                       NaN            NaN
# 15628                    NaN                       NaN            NaN
# 15629                    NaN                       NaN            NaN
# 15630                    NaN                       NaN            NaN
# 15631                    NaN                       NaN            NaN
# 15632                    NaN                       NaN            NaN
# 15633                    NaN                       NaN            NaN
#
#        AVG_ANNULUS_PRESS  AVG_CHOKE_SIZE_P AVG_CHOKE_UOM  AVG_WHP_P  \
# 15624              0.287           0.57510             %      0.085
# 15625              0.283           0.57146             %      0.085
# 15626              0.287           0.56810             %      0.087
# 15627              0.287           0.55897             %      0.085
# 15628              0.285           0.67372             %      0.085
# 15629              0.273           0.63609             %      0.078
# 15630              0.287           0.67079             %      0.085
# 15631              0.286           0.66439             %      0.085
# 15632              0.272           0.62466             %      0.075
# 15633                NaN               NaN           NaN        NaN
#
#        AVG_WHT_P  DP_CHOKE_SIZE  BORE_OIL_VOL  BORE_GAS_VOL  BORE_WAT_VOL  \
# 15624      0.229          0.043           0.0           0.0           0.0
# 15625      0.229          0.040           0.0           0.0           0.0
# 15626      0.229          0.035           0.0           0.0           0.0
# 15627      0.229          0.026           0.0           0.0           0.0
# 15628      0.229          0.037           0.0           0.0           0.0
# 15629      0.229          0.019           0.0           0.0           0.0
# 15630      0.229          0.006           0.0           0.0           0.0
# 15631      0.229          0.012           0.0           0.0           0.0
# 15632      0.228          0.026           0.0           0.0           0.0
# 15633        NaN          0.000           NaN           NaN           NaN
#
#        BORE_WI_VOL   FLOW_KIND WELL_TYPE
# 15624          0.0  production        WI
# 15625          0.0  production        WI
# 15626          0.0  production        WI
# 15627          0.0  production        WI
# 15628          NaN  production        OP
# 15629          NaN  production        OP
# 15630          NaN  production        OP
# 15631          NaN  production        OP
# 15632          NaN  production        OP
# 15633          0.0   injection        WI

# %%
#shape
volve.shape
# Out:
# (15634, 19)

# %%
#columns to get output of columns name
volve.columns
# Out:
# Index(['DATEPRD', 'NPD_WELL_BORE_CODE', 'NPD_WELL_BORE_NAME', 'ON_STREAM_HRS',
#        'AVG_DOWNHOLE_PRESSURE', 'AVG_DOWNHOLE_TEMPERATURE', 'AVG_DP_TUBING',
#        'AVG_ANNULUS_PRESS', 'AVG_CHOKE_SIZE_P', 'AVG_CHOKE_UOM', 'AVG_WHP_P',
#        'AVG_WHT_P', 'DP_CHOKE_SIZE', 'BORE_OIL_VOL', 'BORE_GAS_VOL',
#        'BORE_WAT_VOL', 'BORE_WI_VOL', 'FLOW_KIND', 'WELL_TYPE'],
#       dtype='object')

# %%
volve['NPD_WELL_BORE_NAME'].value_counts()
# Out:
# 15/9-F-4       3327
# 15/9-F-5       3306
# 15/9-F-12      3056
# 15/9-F-14      3056
# 15/9-F-11      1165
# 15/9-F-15 D     978
# 15/9-F-1 C      746
# Name: NPD_WELL_BORE_NAME, dtype: int64

# %%
volve['NPD_WELL_BORE_NAME'] == '15/9-F-12'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 15629    False
# 15630    False
# 15631    False
# 15632    False
# 15633    False
# Name: NPD_WELL_BORE_NAME, Length: 15634, dtype: bool

# %%
#Conditional Dataframe Slicing
pf12 =  volve['NPD_WELL_BORE_NAME'] == '15/9-F-12' #Give Boolean
pf12
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 15629    False
# 15630    False
# 15631    False
# 15632    False
# 15633    False
# Name: NPD_WELL_BORE_NAME, Length: 15634, dtype: bool

# %%
volve_pf12 = volve[pf12]

# %%
volve_pf12
# Out:
#         DATEPRD  NPD_WELL_BORE_CODE NPD_WELL_BORE_NAME  ON_STREAM_HRS  \
# 1911  12-Feb-08                5599          15/9-F-12          11.50
# 1912  13-Feb-08                5599          15/9-F-12          24.00
# 1913  14-Feb-08                5599          15/9-F-12          22.50
# 1914  15-Feb-08                5599          15/9-F-12          23.15
# 1915  16-Feb-08                5599          15/9-F-12          24.00
# ...         ...                 ...                ...            ...
# 4962  13-Sep-16                5599          15/9-F-12           0.00
# 4963  14-Sep-16                5599          15/9-F-12           0.00
# 4964  15-Sep-16                5599          15/9-F-12           0.00
# 4965  16-Sep-16                5599          15/9-F-12           0.00
# 4966  17-Sep-16                5599          15/9-F-12           0.00
#
#       AVG_DOWNHOLE_PRESSURE  AVG_DOWNHOLE_TEMPERATURE  AVG_DP_TUBING  \
# 1911                308.056                   104.418        201.250
# 1912                303.034                   105.403        182.145
# 1913                295.586                   105.775        181.868
# 1914                297.663                   105.752        180.832
# 1915                295.936                   105.811        180.501
# ...                     ...                       ...            ...
# 4962                  0.000                     0.000          0.000
# 4963                  0.000                     0.000          0.000
# 4964                  0.000                     0.000          0.000
# 4965                  0.000                     0.000          0.000
# 4966                  0.000                     0.000          0.000
#
#       AVG_ANNULUS_PRESS  AVG_CHOKE_SIZE_P AVG_CHOKE_UOM  AVG_WHP_P  AVG_WHT_P  \
# 1911             18.640          14.48443             %    106.806     16.295
# 1912             16.467          22.83299             %    120.889     53.374
# 1913             12.660          31.24997             %    113.718     72.738
# 1914              5.264          28.51893             %    116.831     69.996
# 1915             12.385          30.22790             %    115.434     71.518
# ...                 ...               ...           ...        ...        ...
# 4962             19.959           0.99291             %      0.000      0.000
# 4963             19.959           0.97304             %      0.000      0.000
# 4964             19.959           0.97778             %      0.000      0.000
# 4965             19.959           0.96101             %      0.000      0.000
# 4966             19.959           0.90339             %      0.000      0.000
#
#       DP_CHOKE_SIZE  BORE_OIL_VOL  BORE_GAS_VOL  BORE_WAT_VOL  BORE_WI_VOL  \
# 1911         92.475         285.0       38889.0         385.0          NaN
# 1912         89.620        1870.0      285246.0           7.0          NaN
# 1913         80.120        3124.0      509955.0           1.0          NaN
# 1914         84.251        2608.0      383427.0           1.0          NaN
# 1915         82.359        3052.0      418474.0           5.0          NaN
# ...             ...           ...           ...           ...          ...
# 4962          0.013           0.0           0.0           0.0          NaN
# 4963          0.016           0.0           0.0           0.0          NaN
# 4964          0.024           0.0           0.0           0.0          NaN
# 4965          0.025           0.0           0.0           0.0          NaN
# 4966          0.026           0.0           0.0           0.0          NaN
#
#        FLOW_KIND WELL_TYPE
# 1911  production        OP
# 1912  production        OP
# 1913  production        OP
# 1914  production        OP
# 1915  production        OP
# ...          ...       ...
# 4962  production        OP
# 4963  production        OP
# 4964  production        OP
# 4965  production        OP
# 4966  production        OP
#
# [3056 rows x 19 columns]

# %%
volve_pf12.head()
# Out:
#         DATEPRD  NPD_WELL_BORE_CODE NPD_WELL_BORE_NAME  ON_STREAM_HRS  \
# 1911  12-Feb-08                5599          15/9-F-12          11.50
# 1912  13-Feb-08                5599          15/9-F-12          24.00
# 1913  14-Feb-08                5599          15/9-F-12          22.50
# 1914  15-Feb-08                5599          15/9-F-12          23.15
# 1915  16-Feb-08                5599          15/9-F-12          24.00
#
#       AVG_DOWNHOLE_PRESSURE  AVG_DOWNHOLE_TEMPERATURE  AVG_DP_TUBING  \
# 1911                308.056                   104.418        201.250
# 1912                303.034                   105.403        182.145
# 1913                295.586                   105.775        181.868
# 1914                297.663                   105.752        180.832
# 1915                295.936                   105.811        180.501
#
#       AVG_ANNULUS_PRESS  AVG_CHOKE_SIZE_P AVG_CHOKE_UOM  AVG_WHP_P  AVG_WHT_P  \
# 1911             18.640          14.48443             %    106.806     16.295
# 1912             16.467          22.83299             %    120.889     53.374
# 1913             12.660          31.24997             %    113.718     72.738
# 1914              5.264          28.51893             %    116.831     69.996
# 1915             12.385          30.22790             %    115.434     71.518
#
#       DP_CHOKE_SIZE  BORE_OIL_VOL  BORE_GAS_VOL  BORE_WAT_VOL  BORE_WI_VOL  \
# 1911         92.475         285.0       38889.0         385.0          NaN
# 1912         89.620        1870.0      285246.0           7.0          NaN
# 1913         80.120        3124.0      509955.0           1.0          NaN
# 1914         84.251        2608.0      383427.0           1.0          NaN
# 1915         82.359        3052.0      418474.0           5.0          NaN
#
#        FLOW_KIND WELL_TYPE
# 1911  production        OP
# 1912  production        OP
# 1913  production        OP
# 1914  production        OP
# 1915  production        OP

# %%
#info: Information of datatypes and count of null values
volve_pf12.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3056 entries, 1911 to 4966
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   DATEPRD                   3056 non-null   object
#  1   NPD_WELL_BORE_CODE        3056 non-null   int64
#  2   NPD_WELL_BORE_NAME        3056 non-null   object
#  3   ON_STREAM_HRS             3056 non-null   float64
#  4   AVG_DOWNHOLE_PRESSURE     3050 non-null   float64
#  5   AVG_DOWNHOLE_TEMPERATURE  3050 non-null   float64
#  6   AVG_DP_TUBING             3050 non-null   float64
#  7   AVG_ANNULUS_PRESS         3043 non-null   float64
#  8   AVG_CHOKE_SIZE_P          3012 non-null   float64
#  9   AVG_CHOKE_UOM             3056 non-null   object
#  10  AVG_WHP_P                 3056 non-null   float64
#  11  AVG_WHT_P                 3056 non-null   float64
#  12  DP_CHOKE_SIZE             3056 non-null   float64
#  13  BORE_OIL_VOL              3056 non-null   float64
#  14  BORE_GAS_VOL              3056 non-null   float64
#  15  BORE_WAT_VOL              3056 non-null   float64
#  16  BORE_WI_VOL               0 non-null      float64
#  17  FLOW_KIND                 3056 non-null   object
#  18  WELL_TYPE                 3056 non-null   object
# dtypes: float64(13), int64(1), object(5)
# memory usage: 477.5+ KB

# %%
pd.to_datetime(volve_pf12['DATEPRD'])
# Out:
# 1911   2008-02-12
# 1912   2008-02-13
# 1913   2008-02-14
# 1914   2008-02-15
# 1915   2008-02-16
#           ...
# 4962   2016-09-13
# 4963   2016-09-14
# 4964   2016-09-15
# 4965   2016-09-16
# 4966   2016-09-17
# Name: DATEPRD, Length: 3056, dtype: datetime64[ns]

# %%
volve_pf12.set_index(pd.to_datetime(volve_pf12['DATEPRD']),inplace = True)

# %%
volve_pf12
# Out:
#               DATEPRD  NPD_WELL_BORE_CODE NPD_WELL_BORE_NAME  ON_STREAM_HRS  \
# DATEPRD
# 2008-02-12  12-Feb-08                5599          15/9-F-12          11.50
# 2008-02-13  13-Feb-08                5599          15/9-F-12          24.00
# 2008-02-14  14-Feb-08                5599          15/9-F-12          22.50
# 2008-02-15  15-Feb-08                5599          15/9-F-12          23.15
# 2008-02-16  16-Feb-08                5599          15/9-F-12          24.00
# ...               ...                 ...                ...            ...
# 2016-09-13  13-Sep-16                5599          15/9-F-12           0.00
# 2016-09-14  14-Sep-16                5599          15/9-F-12           0.00
# 2016-09-15  15-Sep-16                5599          15/9-F-12           0.00
# 2016-09-16  16-Sep-16                5599          15/9-F-12           0.00
# 2016-09-17  17-Sep-16                5599          15/9-F-12           0.00
#
#             AVG_DOWNHOLE_PRESSURE  AVG_DOWNHOLE_TEMPERATURE  AVG_DP_TUBING  \
# DATEPRD
# 2008-02-12                308.056                   104.418        201.250
# 2008-02-13                303.034                   105.403        182.145
# 2008-02-14                295.586                   105.775        181.868
# 2008-02-15                297.663                   105.752        180.832
# 2008-02-16                295.936                   105.811        180.501
# ...                           ...                       ...            ...
# 2016-09-13                  0.000                     0.000          0.000
# 2016-09-14                  0.000                     0.000          0.000
# 2016-09-15                  0.000                     0.000          0.000
# 2016-09-16                  0.000                     0.000          0.000
# 2016-09-17                  0.000                     0.000          0.000
#
#             AVG_ANNULUS_PRESS  AVG_CHOKE_SIZE_P AVG_CHOKE_UOM  AVG_WHP_P  \
# DATEPRD
# 2008-02-12             18.640          14.48443             %    106.806
# 2008-02-13             16.467          22.83299             %    120.889
# 2008-02-14             12.660          31.24997             %    113.718
# 2008-02-15              5.264          28.51893             %    116.831
# 2008-02-16             12.385          30.22790             %    115.434
# ...                       ...               ...           ...        ...
# 2016-09-13             19.959           0.99291             %      0.000
# 2016-09-14             19.959           0.97304             %      0.000
# 2016-09-15             19.959           0.97778             %      0.000
# 2016-09-16             19.959           0.96101             %      0.000
# 2016-09-17             19.959           0.90339             %      0.000
#
#             AVG_WHT_P  DP_CHOKE_SIZE  BORE_OIL_VOL  BORE_GAS_VOL  \
# DATEPRD
# 2008-02-12     16.295         92.475         285.0       38889.0
# 2008-02-13     53.374         89.620        1870.0      285246.0
# 2008-02-14     72.738         80.120        3124.0      509955.0
# 2008-02-15     69.996         84.251        2608.0      383427.0
# 2008-02-16     71.518         82.359        3052.0      418474.0
# ...               ...            ...           ...           ...
# 2016-09-13      0.000          0.013           0.0           0.0
# 2016-09-14      0.000          0.016           0.0           0.0
# 2016-09-15      0.000          0.024           0.0           0.0
# 2016-09-16      0.000          0.025           0.0           0.0
# 2016-09-17      0.000          0.026           0.0           0.0
#
#             BORE_WAT_VOL  BORE_WI_VOL   FLOW_KIND WELL_TYPE
# DATEPRD
# 2008-02-12         385.0          NaN  production        OP
# 2008-02-13           7.0          NaN  production        OP
# 2008-02-14           1.0          NaN  production        OP
# 2008-02-15           1.0          NaN  production        OP
# 2008-02-16           5.0          NaN  production        OP
# ...                  ...          ...         ...       ...
# 2016-09-13           0.0          NaN  production        OP
# 2016-09-14           0.0          NaN  production        OP
# 2016-09-15           0.0          NaN  production        OP
# 2016-09-16           0.0          NaN  production        OP
# 2016-09-17           0.0          NaN  production        OP
#
# [3056 rows x 19 columns]

# %%
volve_pf12 = volve_pf12.drop("DATEPRD",axis=1)

# %%
volve_pf12.head()
# Out:
#             NPD_WELL_BORE_CODE NPD_WELL_BORE_NAME  ON_STREAM_HRS  \
# DATEPRD
# 2008-02-12                5599          15/9-F-12          11.50
# 2008-02-13                5599          15/9-F-12          24.00
# 2008-02-14                5599          15/9-F-12          22.50
# 2008-02-15                5599          15/9-F-12          23.15
# 2008-02-16                5599          15/9-F-12          24.00
#
#             AVG_DOWNHOLE_PRESSURE  AVG_DOWNHOLE_TEMPERATURE  AVG_DP_TUBING  \
# DATEPRD
# 2008-02-12                308.056                   104.418        201.250
# 2008-02-13                303.034                   105.403        182.145
# 2008-02-14                295.586                   105.775        181.868
# 2008-02-15                297.663                   105.752        180.832
# 2008-02-16                295.936                   105.811        180.501
#
#             AVG_ANNULUS_PRESS  AVG_CHOKE_SIZE_P AVG_CHOKE_UOM  AVG_WHP_P  \
# DATEPRD
# 2008-02-12             18.640          14.48443             %    106.806
# 2008-02-13             16.467          22.83299             %    120.889
# 2008-02-14             12.660          31.24997             %    113.718
# 2008-02-15              5.264          28.51893             %    116.831
# 2008-02-16             12.385          30.22790             %    115.434
#
#             AVG_WHT_P  DP_CHOKE_SIZE  BORE_OIL_VOL  BORE_GAS_VOL  \
# DATEPRD
# 2008-02-12     16.295         92.475         285.0       38889.0
# 2008-02-13     53.374         89.620        1870.0      285246.0
# 2008-02-14     72.738         80.120        3124.0      509955.0
# 2008-02-15     69.996         84.251        2608.0      383427.0
# 2008-02-16     71.518         82.359        3052.0      418474.0
#
#             BORE_WAT_VOL  BORE_WI_VOL   FLOW_KIND WELL_TYPE
# DATEPRD
# 2008-02-12         385.0          NaN  production        OP
# 2008-02-13           7.0          NaN  production        OP
# 2008-02-14           1.0          NaN  production        OP
# 2008-02-15           1.0          NaN  production        OP
# 2008-02-16           5.0          NaN  production        OP

# %%
volve_pf12.index
# Out:
# DatetimeIndex(['2008-02-12', '2008-02-13', '2008-02-14', '2008-02-15',
#                '2008-02-16', '2008-02-17', '2008-02-18', '2008-02-19',
#                '2008-02-20', '2008-02-21',
#                ...
#                '2016-09-08', '2016-09-09', '2016-09-10', '2016-09-11',
#                '2016-09-12', '2016-09-13', '2016-09-14', '2016-09-15',
#                '2016-09-16', '2016-09-17'],
#               dtype='datetime64[ns]', name='DATEPRD', length=3056, freq=None)

# %%
volve_pf12.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3056 entries, 2008-02-12 to 2016-09-17
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   NPD_WELL_BORE_CODE        3056 non-null   int64
#  1   NPD_WELL_BORE_NAME        3056 non-null   object
#  2   ON_STREAM_HRS             3056 non-null   float64
#  3   AVG_DOWNHOLE_PRESSURE     3050 non-null   float64
#  4   AVG_DOWNHOLE_TEMPERATURE  3050 non-null   float64
#  5   AVG_DP_TUBING             3050 non-null   float64
#  6   AVG_ANNULUS_PRESS         3043 non-null   float64
#  7   AVG_CHOKE_SIZE_P          3012 non-null   float64
#  8   AVG_CHOKE_UOM             3056 non-null   object
#  9   AVG_WHP_P                 3056 non-null   float64
#  10  AVG_WHT_P                 3056 non-null   float64
#  11  DP_CHOKE_SIZE             3056 non-null   float64
#  12  BORE_OIL_VOL              3056 non-null   float64
#  13  BORE_GAS_VOL              3056 non-null   float64
#  14  BORE_WAT_VOL              3056 non-null   float64
#  15  BORE_WI_VOL               0 non-null      float64
#  16  FLOW_KIND                 3056 non-null   object
#  17  WELL_TYPE                 3056 non-null   object
# dtypes: float64(13), int64(1), object(4)
# memory usage: 453.6+ KB

# %%
volve_pf12.isnull()
# Out:
#             NPD_WELL_BORE_CODE  NPD_WELL_BORE_NAME  ON_STREAM_HRS  \
# DATEPRD
# 2008-02-12               False               False          False
# 2008-02-13               False               False          False
# 2008-02-14               False               False          False
# 2008-02-15               False               False          False
# 2008-02-16               False               False          False
# ...                        ...                 ...            ...
# 2016-09-13               False               False          False
# 2016-09-14               False               False          False
# 2016-09-15               False               False          False
# 2016-09-16               False               False          False
# 2016-09-17               False               False          False
#
#             AVG_DOWNHOLE_PRESSURE  AVG_DOWNHOLE_TEMPERATURE  AVG_DP_TUBING  \
# DATEPRD
# 2008-02-12                  False                     False          False
# 2008-02-13                  False                     False          False
# 2008-02-14                  False                     False          False
# 2008-02-15                  False                     False          False
# 2008-02-16                  False                     False          False
# ...                           ...                       ...            ...
# 2016-09-13                  False                     False          False
# 2016-09-14                  False                     False          False
# 2016-09-15                  False                     False          False
# 2016-09-16                  False                     False          False
# 2016-09-17                  False                     False          False
#
#             AVG_ANNULUS_PRESS  AVG_CHOKE_SIZE_P  AVG_CHOKE_UOM  AVG_WHP_P  \
# DATEPRD
# 2008-02-12              False             False          False      False
# 2008-02-13              False             False          False      False
# 2008-02-14              False             False          False      False
# 2008-02-15              False             False          False      False
# 2008-02-16              False             False          False      False
# ...                       ...               ...            ...        ...
# 2016-09-13              False             False          False      False
# 2016-09-14              False             False          False      False
# 2016-09-15              False             False          False      False
# 2016-09-16              False             False          False      False
# 2016-09-17              False             False          False      False
#
#             AVG_WHT_P  DP_CHOKE_SIZE  BORE_OIL_VOL  BORE_GAS_VOL  \
# DATEPRD
# 2008-02-12      False          False         False         False
# 2008-02-13      False          False         False         False
# 2008-02-14      False          False         False         False
# 2008-02-15      False          False         False         False
# 2008-02-16      False          False         False         False
# ...               ...            ...           ...           ...
# 2016-09-13      False          False         False         False
# 2016-09-14      False          False         False         False
# 2016-09-15      False          False         False         False
# 2016-09-16      False          False         False         False
# 2016-09-17      False          False         False         False
#
#             BORE_WAT_VOL  BORE_WI_VOL  FLOW_KIND  WELL_TYPE
# DATEPRD
# 2008-02-12         False         True      False      False
# 2008-02-13         False         True      False      False
# 2008-02-14         False         True      False      False
# 2008-02-15         False         True      False      False
# 2008-02-16         False         True      False      False
# ...                  ...          ...        ...        ...
# 2016-09-13         False         True      False      False
# 2016-09-14         False         True      False      False
# 2016-09-15         False         True      False      False
# 2016-09-16         False         True      False      False
# 2016-09-17         False         True      False      False
#
# [3056 rows x 18 columns]

# %%
True ==1
# Out:
# True

# %%
False==0
# Out:
# True

# %%
import seaborn as sns
sns.heatmap(volve_pf12.isnull())
# Out:
# <AxesSubplot:ylabel='DATEPRD'>

# %%
volve_pf12.isnull().sum()
# Out:
# NPD_WELL_BORE_CODE             0
# NPD_WELL_BORE_NAME             0
# ON_STREAM_HRS                  0
# AVG_DOWNHOLE_PRESSURE          6
# AVG_DOWNHOLE_TEMPERATURE       6
# AVG_DP_TUBING                  6
# AVG_ANNULUS_PRESS             13
# AVG_CHOKE_SIZE_P              44
# AVG_CHOKE_UOM                  0
# AVG_WHP_P                      0
# AVG_WHT_P                      0
# DP_CHOKE_SIZE                  0
# BORE_OIL_VOL                   0
# BORE_GAS_VOL                   0
# BORE_WAT_VOL                   0
# BORE_WI_VOL                 3056
# FLOW_KIND                      0
# WELL_TYPE                      0
# dtype: int64

# %%
#Accessing a column
volve_pf12['AVG_DOWNHOLE_PRESSURE']
# Out:
# DATEPRD
# 2008-02-12    308.056
# 2008-02-13    303.034
# 2008-02-14    295.586
# 2008-02-15    297.663
# 2008-02-16    295.936
#                ...
# 2016-09-13      0.000
# 2016-09-14      0.000
# 2016-09-15      0.000
# 2016-09-16      0.000
# 2016-09-17      0.000
# Name: AVG_DOWNHOLE_PRESSURE, Length: 3056, dtype: float64

# %%
volve_pf12[['AVG_DOWNHOLE_PRESSURE']]
# Out:
#             AVG_DOWNHOLE_PRESSURE
# DATEPRD
# 2008-02-12                308.056
# 2008-02-13                303.034
# 2008-02-14                295.586
# 2008-02-15                297.663
# 2008-02-16                295.936
# ...                           ...
# 2016-09-13                  0.000
# 2016-09-14                  0.000
# 2016-09-15                  0.000
# 2016-09-16                  0.000
# 2016-09-17                  0.000
#
# [3056 rows x 1 columns]

# %%
a =volve_pf12[['AVG_DOWNHOLE_PRESSURE','BORE_OIL_VOL']]

# %%
a
# Out:
#             AVG_DOWNHOLE_PRESSURE  BORE_OIL_VOL
# DATEPRD
# 2008-02-12                308.056         285.0
# 2008-02-13                303.034        1870.0
# 2008-02-14                295.586        3124.0
# 2008-02-15                297.663        2608.0
# 2008-02-16                295.936        3052.0
# ...                           ...           ...
# 2016-09-13                  0.000           0.0
# 2016-09-14                  0.000           0.0
# 2016-09-15                  0.000           0.0
# 2016-09-16                  0.000           0.0
# 2016-09-17                  0.000           0.0
#
# [3056 rows x 2 columns]

# %%
volve_pf12
# Out:
#             NPD_WELL_BORE_CODE NPD_WELL_BORE_NAME  ON_STREAM_HRS  \
# DATEPRD
# 2008-02-12                5599          15/9-F-12          11.50
# 2008-02-13                5599          15/9-F-12          24.00
# 2008-02-14                5599          15/9-F-12          22.50
# 2008-02-15                5599          15/9-F-12          23.15
# 2008-02-16                5599          15/9-F-12          24.00
# ...                        ...                ...            ...
# 2016-09-13                5599          15/9-F-12           0.00
# 2016-09-14                5599          15/9-F-12           0.00
# 2016-09-15                5599          15/9-F-12           0.00
# 2016-09-16                5599          15/9-F-12           0.00
# 2016-09-17                5599          15/9-F-12           0.00
#
#             AVG_DOWNHOLE_PRESSURE  AVG_DOWNHOLE_TEMPERATURE  AVG_DP_TUBING  \
# DATEPRD
# 2008-02-12                308.056                   104.418        201.250
# 2008-02-13                303.034                   105.403        182.145
# 2008-02-14                295.586                   105.775        181.868
# 2008-02-15                297.663                   105.752        180.832
# 2008-02-16                295.936                   105.811        180.501
# ...                           ...                       ...            ...
# 2016-09-13                  0.000                     0.000          0.000
# 2016-09-14                  0.000                     0.000          0.000
# 2016-09-15                  0.000                     0.000          0.000
# 2016-09-16                  0.000                     0.000          0.000
# 2016-09-17                  0.000                     0.000          0.000
#
#             AVG_ANNULUS_PRESS  AVG_CHOKE_SIZE_P AVG_CHOKE_UOM  AVG_WHP_P  \
# DATEPRD
# 2008-02-12             18.640          14.48443             %    106.806
# 2008-02-13             16.467          22.83299             %    120.889
# 2008-02-14             12.660          31.24997             %    113.718
# 2008-02-15              5.264          28.51893             %    116.831
# 2008-02-16             12.385          30.22790             %    115.434
# ...                       ...               ...           ...        ...
# 2016-09-13             19.959           0.99291             %      0.000
# 2016-09-14             19.959           0.97304             %      0.000
# 2016-09-15             19.959           0.97778             %      0.000
# 2016-09-16             19.959           0.96101             %      0.000
# 2016-09-17             19.959           0.90339             %      0.000
#
#             AVG_WHT_P  DP_CHOKE_SIZE  BORE_OIL_VOL  BORE_GAS_VOL  \
# DATEPRD
# 2008-02-12     16.295         92.475         285.0       38889.0
# 2008-02-13     53.374         89.620        1870.0      285246.0
# 2008-02-14     72.738         80.120        3124.0      509955.0
# 2008-02-15     69.996         84.251        2608.0      383427.0
# 2008-02-16     71.518         82.359        3052.0      418474.0
# ...               ...            ...           ...           ...
# 2016-09-13      0.000          0.013           0.0           0.0
# 2016-09-14      0.000          0.016           0.0           0.0
# 2016-09-15      0.000          0.024           0.0           0.0
# 2016-09-16      0.000          0.025           0.0           0.0
# 2016-09-17      0.000          0.026           0.0           0.0
#
#             BORE_WAT_VOL  BORE_WI_VOL   FLOW_KIND WELL_TYPE
# DATEPRD
# 2008-02-12         385.0          NaN  production        OP
# 2008-02-13           7.0          NaN  production        OP
# 2008-02-14           1.0          NaN  production        OP
# 2008-02-15           1.0          NaN  production        OP
# 2008-02-16           5.0          NaN  production        OP
# ...                  ...          ...         ...       ...
# 2016-09-13           0.0          NaN  production        OP
# 2016-09-14           0.0          NaN  production        OP
# 2016-09-15           0.0          NaN  production        OP
# 2016-09-16           0.0          NaN  production        OP
# 2016-09-17           0.0          NaN  production        OP
#
# [3056 rows x 18 columns]

# %%
#accessing through index number
volve_pf12.iloc[2]
# Out:
# NPD_WELL_BORE_CODE                  5599
# NPD_WELL_BORE_NAME             15/9-F-12
# ON_STREAM_HRS                   22.50000
# AVG_DOWNHOLE_PRESSURE          295.58600
# AVG_DOWNHOLE_TEMPERATURE       105.77500
# AVG_DP_TUBING                  181.86800
# AVG_ANNULUS_PRESS               12.66000
# AVG_CHOKE_SIZE_P                31.24997
# AVG_CHOKE_UOM                          %
# AVG_WHP_P                      113.71800
# AVG_WHT_P                       72.73800
# DP_CHOKE_SIZE                   80.12000
# BORE_OIL_VOL                  3124.00000
# BORE_GAS_VOL                509955.00000
# BORE_WAT_VOL                     1.00000
# BORE_WI_VOL                          NaN
# FLOW_KIND                     production
# WELL_TYPE                             OP
# Name: 2008-02-14 00:00:00, dtype: object

# %%
#index name
volve_pf12.loc['2008-02-14']
# Out:
# NPD_WELL_BORE_CODE                  5599
# NPD_WELL_BORE_NAME             15/9-F-12
# ON_STREAM_HRS                   22.50000
# AVG_DOWNHOLE_PRESSURE          295.58600
# AVG_DOWNHOLE_TEMPERATURE       105.77500
# AVG_DP_TUBING                  181.86800
# AVG_ANNULUS_PRESS               12.66000
# AVG_CHOKE_SIZE_P                31.24997
# AVG_CHOKE_UOM                          %
# AVG_WHP_P                      113.71800
# AVG_WHT_P                       72.73800
# DP_CHOKE_SIZE                   80.12000
# BORE_OIL_VOL                  3124.00000
# BORE_GAS_VOL                509955.00000
# BORE_WAT_VOL                     1.00000
# BORE_WI_VOL                          NaN
# FLOW_KIND                     production
# WELL_TYPE                             OP
# Name: 2008-02-14 00:00:00, dtype: object

# %%
volve_pf12
# Out:
#             NPD_WELL_BORE_CODE NPD_WELL_BORE_NAME  ON_STREAM_HRS  \
# DATEPRD
# 2008-02-12                5599          15/9-F-12          11.50
# 2008-02-13                5599          15/9-F-12          24.00
# 2008-02-14                5599          15/9-F-12          22.50
# 2008-02-15                5599          15/9-F-12          23.15
# 2008-02-16                5599          15/9-F-12          24.00
# ...                        ...                ...            ...
# 2016-09-13                5599          15/9-F-12           0.00
# 2016-09-14                5599          15/9-F-12           0.00
# 2016-09-15                5599          15/9-F-12           0.00
# 2016-09-16                5599          15/9-F-12           0.00
# 2016-09-17                5599          15/9-F-12           0.00
#
#             AVG_DOWNHOLE_PRESSURE  AVG_DOWNHOLE_TEMPERATURE  AVG_DP_TUBING  \
# DATEPRD
# 2008-02-12                308.056                   104.418        201.250
# 2008-02-13                303.034                   105.403        182.145
# 2008-02-14                295.586                   105.775        181.868
# 2008-02-15                297.663                   105.752        180.832
# 2008-02-16                295.936                   105.811        180.501
# ...                           ...                       ...            ...
# 2016-09-13                  0.000                     0.000          0.000
# 2016-09-14                  0.000                     0.000          0.000
# 2016-09-15                  0.000                     0.000          0.000
# 2016-09-16                  0.000                     0.000          0.000
# 2016-09-17                  0.000                     0.000          0.000
#
#             AVG_ANNULUS_PRESS  AVG_CHOKE_SIZE_P AVG_CHOKE_UOM  AVG_WHP_P  \
# DATEPRD
# 2008-02-12             18.640          14.48443             %    106.806
# 2008-02-13             16.467          22.83299             %    120.889
# 2008-02-14             12.660          31.24997             %    113.718
# 2008-02-15              5.264          28.51893             %    116.831
# 2008-02-16             12.385          30.22790             %    115.434
# ...                       ...               ...           ...        ...
# 2016-09-13             19.959           0.99291             %      0.000
# 2016-09-14             19.959           0.97304             %      0.000
# 2016-09-15             19.959           0.97778             %      0.000
# 2016-09-16             19.959           0.96101             %      0.000
# 2016-09-17             19.959           0.90339             %      0.000
#
#             AVG_WHT_P  DP_CHOKE_SIZE  BORE_OIL_VOL  BORE_GAS_VOL  \
# DATEPRD
# 2008-02-12     16.295         92.475         285.0       38889.0
# 2008-02-13     53.374         89.620        1870.0      285246.0
# 2008-02-14     72.738         80.120        3124.0      509955.0
# 2008-02-15     69.996         84.251        2608.0      383427.0
# 2008-02-16     71.518         82.359        3052.0      418474.0
# ...               ...            ...           ...           ...
# 2016-09-13      0.000          0.013           0.0           0.0
# 2016-09-14      0.000          0.016           0.0           0.0
# 2016-09-15      0.000          0.024           0.0           0.0
# 2016-09-16      0.000          0.025           0.0           0.0
# 2016-09-17      0.000          0.026           0.0           0.0
#
#             BORE_WAT_VOL  BORE_WI_VOL   FLOW_KIND WELL_TYPE
# DATEPRD
# 2008-02-12         385.0          NaN  production        OP
# 2008-02-13           7.0          NaN  production        OP
# 2008-02-14           1.0          NaN  production        OP
# 2008-02-15           1.0          NaN  production        OP
# 2008-02-16           5.0          NaN  production        OP
# ...                  ...          ...         ...       ...
# 2016-09-13           0.0          NaN  production        OP
# 2016-09-14           0.0          NaN  production        OP
# 2016-09-15           0.0          NaN  production        OP
# 2016-09-16           0.0          NaN  production        OP
# 2016-09-17           0.0          NaN  production        OP
#
# [3056 rows x 18 columns]

# %%
volve_pf12['AVG_DOWNHOLE_PRESSURE']['2008-02-14']
# Out:
# 295.586

# %%
#Plotting the values with value of date on x axis
#inbuilt plot function of pandas
volve_pf12.plot(figsize = (12,10),subplots= True)
# Out:
# array([<AxesSubplot:xlabel='DATEPRD'>, <AxesSubplot:xlabel='DATEPRD'>,
#        <AxesSubplot:xlabel='DATEPRD'>, <AxesSubplot:xlabel='DATEPRD'>,
#        <AxesSubplot:xlabel='DATEPRD'>, <AxesSubplot:xlabel='DATEPRD'>,
#        <AxesSubplot:xlabel='DATEPRD'>, <AxesSubplot:xlabel='DATEPRD'>,
#        <AxesSubplot:xlabel='DATEPRD'>, <AxesSubplot:xlabel='DATEPRD'>,
#        <AxesSubplot:xlabel='DATEPRD'>, <AxesSubplot:xlabel='DATEPRD'>,
#        <AxesSubplot:xlabel='DATEPRD'>, <AxesSubplot:xlabel='DATEPRD'>],
#       dtype=object)

# %%
plt.figure(figsize=(15,6))
plt.plot(volve_pf12.index,volve_pf12['BORE_OIL_VOL'])
